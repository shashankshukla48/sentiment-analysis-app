# %% [markdown]
# Build flas api

# %%
# !pip install Flask
# Out:
# ...
#   Using cached flask-3.1.2-py3-none-any.whl.metadata (3.2 kB)
# ...
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# ...
# Using cached flask-3.1.2-py3-none-any.whl (103 kB)
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# ...
#
#    ---------------------------------------- 0/3 [itsdangerous]
#    -------------------------- ------------- 2/3 [Flask]
#    -------------------------- ------------- 2/3 [Flask]
#    -------------------------- ------------- 2/3 [Flask]
#    -------------------------- ------------- 2/3 [Flask]
#    -------------------------- ------------- 2/3 [Flask]
#    ---------------------------------------- 3/3 [Flask]
#
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Werkzeug: A powerful library that handles the low-level server and request/response logic.
# Jinja2: A templating engine used for rendering HTML (which we won't use for our API, but it's a core part of Flask).
# ItsDangerous: A library for securely signing data.
# Click: A library for creating command-line interfaces.
